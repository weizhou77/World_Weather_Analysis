# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitudes combinations.
# Creats lats and lngs and pair them by zipping them lat_lngs with the zip() function
lats = np.random.uniform(low =  -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 729

# %%
cities
# Out:
# ['lexington',
#  'cherskiy',
#  'atuona',
#  'dikson',
#  'kruisfontein',
#  'esperance',
#  'kapaa',
#  'hovd',
#  'illoqqortoormiut',
#  'busselton',
#  'jamestown',
#  'black river',
#  'puerto ayora',
#  'nikolskoye',
#  'khatanga',
#  'xuddur',
#  'carnarvon',
#  'bambous virieux',
#  'gorom-gorom',
#  'rikitea',
#  'punta arenas',
#  'taolanaro',
#  'east london',
#  'saint-philippe',
#  'hermanus',
#  'ambilobe',
#  'port alfred',
#  'mataura',
#  'hilo',
#  'pevek',
#  'vaini',
#  'tsihombe',
#  'ushuaia',
#  'victoria',
#  'billings',
#  'roma',
#  'bluff',
#  'katsuura',
#  'butaritari',
#  'belushya guba',
#  'ribeira grande',
#  'aklavik',
#  'akyab',
#  'dingle',
#  'castro',
#  'saint anthony',
#  'bredasdorp',
#  'tiznit',
#  'stayner',
#  'chokurdakh',
#  'cabo san lucas',
#  'port blair',
#  'melito di porto salvo',
#  'marienburg',
#  'waingapu',
#  'ancud',
#  'tuatapere',
#  'port lincoln',
#  'bengkulu',
#  'dandong',
#  'hobart',
#  'tire',
#  'cape town',
#  'talcahuano',
#  'one hundred mile house',
#  'arraial do cabo',
#  'mys shmidta',
#  'toora-khem',
#  'rio grande',
#  'barrow',
#  'lebu',
#  'tasiilaq',
#  'boguchany',
#  'meulaboh',
#  'provideniya',
#  'bethel',
#  'pisco',
#  'amderma',
#  'markovo',
#  'avarua',
#  'santa cruz de tenerife',
#  'srednekolymsk',
#  'barentsburg',
#  'hamilton',
#  'lompoc',
#  'vila franca do campo',
#  'visnes',
#  'mayo',
#  'saint-pierre',
#  'attawapiskat',
#  'grants pass',
#  'dawson',
#  'port elizabeth',
#  'kyra',
#  'lasa',
#  'baykit',
#  'airai',
#  'dicabisagan',
#  'karratha',
#  'ngukurr',
#  'russell',
#  'ismailia',
#  'aguimes',
#  'poum',
#  'kargasok',
#  'masindi',
#  'cidreira',
#  'nara',
#  'georgetown',
#  'pandan',
#  'marcona',
#  'kavieng',
#  'upernavik',
#  'sur',
#  'ponta do sol',
#  'lethem',
#  'leningradskiy',
#  'itarsi',
#  'potosi',
#  'santana do matos',
#  'guangyuan',
#  'broome',
#  'beruni',
#  'samusu',
#  'waipawa',
#  'torbay',
#  'beringovskiy',
#  'vostok',
#  'albany',
#  'honningsvag',
#  'yellowknife',
#  'ballina',
#  'kannur',
#  'marsh harbour',
#  'bay roberts',
#  'bilma',
#  'vangaindrano',
#  'codrington',
#  'el ermitano',
#  'mar del plata',
#  'tyumentsevo',
#  'iqaluit',
#  'darhan',
#  'qaanaaq',
#  'buala',
#  'fortuna',
#  'bonavista',
#  'batagay',
#  'faanui',
#  'new norfolk',
#  'komsomolskiy',
#  'bitung',
#  'grand-lahou',
#  'saint-augustin',
#  'spas-demensk',
#  'pomerode',
#  'nguiu',
#  'bathsheba',
#  'sitka',
#  'thompson',
#  'samarai',
#  'hithadhoo',
#  'beamsville',
#  'tashigang',
#  'flin flon',
#  'dudinka',
#  'cairns',
#  'mahebourg',
#  'meteti',
#  'puri',
#  'fatehpur',
#  'eydhafushi',
#  'bolungarvik',
#  'waddan',
#  'kamaishi',
#  'baringo',
#  'vardo',
#  'opuwo',
#  'arman',
#  'aranda de duero',
#  'berlevag',
#  'mattru',
#  'hirson',
#  'san patricio',
#  'angoram',
#  'broken hill',
#  'creel',
#  'talnakh',
#  'mulbagal',
#  'gazanjyk',
#  'muisne',
#  'lorengau',
#  'ostrovnoy',
#  'tucumcari',
#  'tobol',
#  'seoul',
#  'the valley',
#  'yar-sale',
#  'thinadhoo',
#  'puerto del rosario',
#  'hay river',
#  'saint-joseph',
#  'acarau',
#  'hami',
#  'beidao',
#  'port macquarie',
#  'lavrentiya',
#  'alto baudo',
#  'havoysund',
#  'cockburn town',
#  'segovia',
#  'husavik',
#  'rungata',
#  'kodiak',
#  'sorland',
#  'cheuskiny',
#  'kabelvag',
#  'grand river south east',
#  'naze',
#  'kurchum',
#  'beloha',
#  'yarada',
#  'saleaula',
#  'bato',
#  'cayenne',
#  'severo-kurilsk',
#  'tamiahua',
#  'sydney',
#  'preobrazheniye',
#  'barawe',
#  'rusape',
#  'yerbogachen',
#  'raton',
#  'lyubymivka',
#  'asau',
#  'pasni',
#  'kavaratti',
#  'rawson',
#  'pacific grove',
#  'basco',
#  'barguzin',
#  'mabaruma',
#  'koutiala',
#  'sulangan',
#  'fria',
#  'gryfice',
#  'sayyan',
#  'nanortalik',
#  'sovetskaya gavan',
#  'maniitsoq',
#  'paranaiba',
#  'itacarambi',
#  'mosetse',
#  'puerto leguizamo',
#  'ust-nera',
#  'kangaatsiaq',
#  'karymskoye',
#  'west wendover',
#  'nizhneyansk',
#  'rocha',
#  'tonj',
#  'port hardy',
#  'grande prairie',
#  'anadyr',
#  'kiunga',
#  'manasa',
#  'abeche',
#  'igrim',
#  'qasigiannguit',
#  'tra vinh',
#  'belaya gora',
#  'rockhampton',
#  'katherine',
#  'ixtapa',
#  'padang',
#  'santa rita',
#  'praia da vitoria',
#  'fontanka',
#  'nola',
#  'tecoanapa',
#  'jinchengjiang',
#  'los llanos de aridane',
#  'san carlos de bariloche',
#  'rundu',
#  'altay',
#  'casalpusterlengo',
#  'wasilla',
#  'gunjur',
#  'pinawa',
#  'sioux lookout',
#  'sobolevo',
#  'pak phanang',
#  'necochea',
#  'zhigalovo',
#  'les cayes',
#  'ocos',
#  'tynda',
#  'charters towers',
#  'belmonte',
#  'lamont',
#  'naantali',
#  'ivdel',
#  'hasaki',
#  'ous',
#  'ayan',
#  'pointe michel',
#  'candolim',
#  'mana',
#  'nan',
#  'fatehgarh',
#  'alta floresta',
#  'umm jarr',
#  'saldanha',
#  'dubbo',
#  'kaitangata',
#  'san quintin',
#  'catamarca',
#  'barcelos',
#  'bowen',
#  'pangai',
#  'bargal',
#  'tapaua',
#  'burica',
#  'wajir',
#  'ketchikan',
#  'tessalit',
#  'sumenep',
#  'auki',
#  'beberibe',
#  'roebourne',
#  'mogadishu',
#  'pasighat',
#  'vostochnyy',
#  'lata',
#  'geraldton',
#  'plattsburgh',
#  'atar',
#  'norman wells',
#  'duncan',
#  'banyo',
#  'faya',
#  'gat',
#  'verkh-usugli',
#  'altamont',
#  'mazulskiy',
#  'fairbanks',
#  'marsa matruh',
#  'harper',
#  'binzhou',
#  'kaeo',
#  'tuktoyaktuk',
#  'henties bay',
#  'yefimovskiy',
#  'naigarhi',
#  'mobara',
#  'mujiayingzi',
#  'husum',
#  'guerrero negro',
#  'te anau',
#  'makakilo city',
#  'esso',
#  'longyearbyen',
#  'montijo',
#  'cangucu',
#  'clyde river',
#  'biak',
#  'fevralsk',
#  'avera',
#  'ginir',
#  'hambantota',
#  'kirakira',
#  'margate',
#  'chulman',
#  'murgab',
#  'sentyabrskiy',
#  'perbaungan',
#  'letterkenny',
#  'floro',
#  'iquitos',
#  'luganville',
#  'bukama',
#  'sola',
#  'ust-kamchatsk',
#  'tumannyy',
#  'saskylakh',
#  'itarema',
#  'grindavik',
#  'alofi',
#  'concepcion del oro',
#  'aflu',
#  'sao joao da barra',
#  'nador',
#  'tairua',
#  'kutum',
#  'coquimbo',
#  'erzin',
#  'la ronge',
#  'tabou',
#  'zheleznodorozhnyy',
#  'quthing',
#  'dien bien',
#  'luderitz',
#  'adwa',
#  'urucara',
#  'marawi',
#  'bull savanna',
#  'sargur',
#  'svetlogorsk',
#  'mehamn',
#  'agropoli',
#  'la asuncion',
#  'saint george',
#  'jinan',
#  'gigmoto',
#  'alto piquiri',
#  'svetlyy',
#  'abancay',
#  'rio tinto',
#  'omboue',
#  'nusaybin',
#  'tautira',
#  'springbok',
#  'winnemucca',
#  'mahanoro',
#  'pangnirtung',
#  'benjamin constant',
#  'senador jose porfirio',
#  'souillac',
#  'arlit',
#  'salinopolis',
#  'asekeyevo',
#  'san onofre',
#  'champerico',
#  'bouna',
#  'moju',
#  'zhaozhou',
#  'ryotsu',
#  'salalah',
#  'batemans bay',
#  'litoral del san juan',
#  'hualmay',
#  'kupino',
#  'ruatoria',
#  'platanos',
#  'zhigansk',
#  'tigil',
#  'severnyy',
#  'taoudenni',
#  'tarudant',
#  'gimli',
#  'bosaso',
#  'valladolid',
#  'tunceli',
#  'udachnyy',
#  'diffa',
#  'lons',
#  'bandarbeyla',
#  'isangel',
#  'porto franco',
#  'lalmohan',
#  'rabat',
#  'onguday',
#  'natal',
#  'sakakah',
#  'san cristobal',
#  'oktyabrskiy',
#  'bambanglipuro',
#  'ambovombe',
#  'qeshm',
#  'aberdeen',
#  'portland',
#  'gizo',
#  'katsiveli',
#  'nobeoka',
#  'dalbandin',
#  'vaitupu',
#  'levelland',
#  'port hawkesbury',
#  'nantucket',
#  'prince rupert',
#  'paamiut',
#  'liancheng',
#  'khani',
#  'sal rei',
#  'port-gentil',
#  'salta',
#  'kanniyakumari',
#  'ouegoa',
#  'uusikaupunki',
#  'guiratinga',
#  'jaipur',
#  'gurskoye',
#  'yinchuan',
#  'san juan de abajo',
#  'darque',
#  'ahipara',
#  'tomino',
#  'bolshiye uki',
#  'amapa',
#  'neuquen',
#  'castilho',
#  'yulara',
#  'mapiripan',
#  'sandpoint',
#  'sao filipe',
#  'baie-comeau',
#  'gao',
#  'el torno',
#  'cabadiangan',
#  'thoen',
#  'ilulissat',
#  'vieux fort',
#  'tiksi',
#  'tual',
#  'namibe',
#  'aguazul',
#  'rapid valley',
#  'warqla',
#  'hutchinson',
#  'jabinyanah',
#  'ahtopol',
#  'labuan',
#  'narsaq',
#  'craig',
#  'whitianga',
#  'bolobo',
#  'comarapa',
#  'matipo',
#  'umtata',
#  'gamba',
#  'benemerito de las americas',
#  'bacolod',
#  'arequipa',
#  'camana',
#  'nkhotakota',
#  'west bay',
#  'mandalgovi',
#  'balkanabat',
#  'puerto baquerizo moreno',
#  'eregli',
#  'celestun',
#  'assiniboia',
#  'waitati',
#  'san vicente',
#  'xai-xai',
#  'abu samrah',
#  'kushiro',
#  'viedma',
#  'motygino',
#  'paysandu',
#  'port hedland',
#  'roseburg',
#  'palora',
#  'maloshuyka',
#  'anchorage',
#  'mao',
#  'kieta',
#  'meadow lake',
#  'talaya',
#  'dwarka',
#  'nakhon thai',
#  'touros',
#  'sibolga',
#  'jalu',
#  'fort saint john',
#  'port moresby',
#  'tromso',
#  'richards bay',
#  'aripuana',
#  'norden',
#  'cabedelo',
#  'lujan',
#  'klaksvik',
#  'diego de almagro',
#  'tagana-an',
#  'macamic',
#  'shubarshi',
#  'olafsvik',
#  'lima',
#  'aksu',
#  'fort nelson',
#  'zabaykalsk',
#  'afmadu',
#  'revda',
#  'manado',
#  'haines junction',
#  'nedjo',
#  'eirunepe',
#  'cervo',
#  'saint-georges',
#  'quelimane',
#  'ormara',
#  'los altos',
#  'macae',
#  'riosucio',
#  'huainan',
#  'kabare',
#  'lishu',
#  'buraydah',
#  'newport',
#  'lixourion',
#  'chuy',
#  'porto novo',
#  'polyarnyy',
#  'northam',
#  'beatrice',
#  'shimoda',
#  'karauzyak',
#  'anzio',
#  'muros',
#  'flinders',
#  'oyama',
#  'matay',
#  'camacha',
#  'inuvik',
#  'whitehorse',
#  'nome',
#  'busca',
#  'kyshtovka',
#  'safaga',
#  'madimba',
#  'horsham',
#  'daoukro',
#  'mecca',
#  'moses lake',
#  'ternate',
#  'makokou',
#  'wanaka',
#  'rexburg',
#  'alice springs',
#  'utiel',
#  'qaqortoq',
#  'slave lake',
#  'inderborskiy',
#  'lubango',
#  'hun',
#  'teya',
#  'hammerfest',
#  'kamina',
#  'haverfordwest',
#  'miram shah',
#  'sault sainte marie',
#  'nemuro',
#  'hofn',
#  'polunochnoye',
#  'kunming',
#  'uray',
#  'nicoya',
#  'sao jose da coroa grande',
#  'kalakamati',
#  'ikalamavony',
#  'uvarovka',
#  'huarmey',
#  'cakovec',
#  'ust-omchug',
#  'windsor',
#  'emerald',
#  'punta alta',
#  'boca do acre',
#  'soni',
#  'tura',
#  'yuzhno-kurilsk',
#  'bonfim',
#  'vanimo',
#  'bereda',
#  'tilichiki',
#  'zaranj',
#  'tecpan',
#  'burnie',
#  'angoche',
#  'arrecife',
#  'meridian',
#  'finschhafen',
#  'martil',
#  'dickinson',
#  'belle fourche',
#  'boa vista',
#  'ilek',
#  'labuhan',
#  'tezu',
#  'igarka',
#  'coihaique',
#  'gravdal',
#  'poso',
#  'marystown',
#  'ihosy',
#  'lagoa',
#  'kuytun',
#  'bam',
#  'bardiyah',
#  'tongliao',
#  'vila velha',
#  'soyo',
#  'valdemarpils',
#  'utiroa',
#  'nanga eboko',
#  'chone',
#  'luoyang',
#  'archidona',
#  'novoagansk',
#  'follonica',
#  'toguchin',
#  'lebedinyy',
#  'divnomorskoye',
#  'thessalon',
#  'elk city',
#  'neiafu',
#  'banbury',
#  'herat',
#  'saint-francois',
#  'doctor arroyo',
#  'wanning',
#  'leh',
#  'popondetta',
#  'krasnokamensk',
#  'oksovskiy',
#  'mosquera',
#  'lesnyye polyany',
#  'tocopilla',
#  'kenai',
#  'bama',
#  'umzimvubu',
#  'nabire',
#  'raudeberg',
#  'mut',
#  'sabaudia',
#  'talakan',
#  'askino',
#  'killam']

# %%
# Import the requests library.
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=87b7a71b915f2ad8471aa596f4425849

# %%
lexington_example = url + "&q=" + "lexington"
lexington_request = requests.get(lexington_example)
lexington_request.json()
# Because the DataFrame request to have the 'description' column, 
# so we read json format to find the 'description'
# Out:
# {'coord': {'lon': -84.4777, 'lat': 37.9887},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 25.92,
#   'feels_like': 18.66,
#   'temp_min': 25.92,
#   'temp_max': 25.92,
#   'pressure': 1023,
#   'humidity': 67,
#   'sea_level': 1023,
#   'grnd_level': 986},
#  'visibility': 10000,
#  'wind': {'speed': 6.38, 'deg': 309, 'gust': 8.93},
#  'clouds': {'all': 43},
#  'dt': 1638178445,
#  'sys': {'country': 'US', 'sunrise': 1638189218, 'sunset': 1638224366},
#  'timezone': -18000,
#  'id': 4297983,
#  'name': 'Lexington',
#  'cod': 200}

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []
# print the beginning of the logging
print("Beginning Data Retrieval   ")
print("---------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ---------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country" : city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_description,
                          "Date" : city_date
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | lexington
# Processing Record 2 of Set 1 | cherskiy
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | esperance
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | hovd
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | black river
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | xuddur
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | bambous virieux
# Processing Record 19 of Set 1 | gorom-gorom
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | ambilobe
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | pevek
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | victoria
# Processing Record 35 of Set 1 | billings
# Processing Record 36 of Set 1 | roma
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | katsuura
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | aklavik
# Processing Record 43 of Set 1 | akyab
# Processing Record 44 of Set 1 | dingle
# Processing Record 45 of Set 1 | castro
# Processing Record 46 of Set 1 | saint anthony
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | tiznit
# Processing Record 49 of Set 1 | stayner
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | cabo san lucas
# Processing Record 2 of Set 2 | port blair
# Processing Record 3 of Set 2 | melito di porto salvo
# Processing Record 4 of Set 2 | marienburg
# Processing Record 5 of Set 2 | waingapu
# Processing Record 6 of Set 2 | ancud
# Processing Record 7 of Set 2 | tuatapere
# Processing Record 8 of Set 2 | port lincoln
# Processing Record 9 of Set 2 | bengkulu
# Processing Record 10 of Set 2 | dandong
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | tire
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | talcahuano
# Processing Record 15 of Set 2 | one hundred mile house
# City not found. Skipping...
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 2 | toora-khem
# Processing Record 19 of Set 2 | rio grande
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | tasiilaq
# Processing Record 23 of Set 2 | boguchany
# Processing Record 24 of Set 2 | meulaboh
# Processing Record 25 of Set 2 | provideniya
# Processing Record 26 of Set 2 | bethel
# Processing Record 27 of Set 2 | pisco
# Processing Record 28 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 2 | markovo
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | santa cruz de tenerife
# Processing Record 32 of Set 2 | srednekolymsk
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | hamilton
# Processing Record 35 of Set 2 | lompoc
# Processing Record 36 of Set 2 | vila franca do campo
# Processing Record 37 of Set 2 | visnes
# Processing Record 38 of Set 2 | mayo
# Processing Record 39 of Set 2 | saint-pierre
# Processing Record 40 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 2 | grants pass
# Processing Record 42 of Set 2 | dawson
# Processing Record 43 of Set 2 | port elizabeth
# Processing Record 44 of Set 2 | kyra
# Processing Record 45 of Set 2 | lasa
# Processing Record 46 of Set 2 | baykit
# Processing Record 47 of Set 2 | airai
# Processing Record 48 of Set 2 | dicabisagan
# Processing Record 49 of Set 2 | karratha
# Processing Record 50 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 3 | russell
# Processing Record 2 of Set 3 | ismailia
# Processing Record 3 of Set 3 | aguimes
# Processing Record 4 of Set 3 | poum
# Processing Record 5 of Set 3 | kargasok
# Processing Record 6 of Set 3 | masindi
# Processing Record 7 of Set 3 | cidreira
# Processing Record 8 of Set 3 | nara
# Processing Record 9 of Set 3 | georgetown
# Processing Record 10 of Set 3 | pandan
# Processing Record 11 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 3 | kavieng
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | sur
# Processing Record 15 of Set 3 | ponta do sol
# Processing Record 16 of Set 3 | lethem
# Processing Record 17 of Set 3 | leningradskiy
# Processing Record 18 of Set 3 | itarsi
# Processing Record 19 of Set 3 | potosi
# Processing Record 20 of Set 3 | santana do matos
# Processing Record 21 of Set 3 | guangyuan
# Processing Record 22 of Set 3 | broome
# Processing Record 23 of Set 3 | beruni
# City not found. Skipping...
# Processing Record 24 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 3 | waipawa
# Processing Record 26 of Set 3 | torbay
# Processing Record 27 of Set 3 | beringovskiy
# Processing Record 28 of Set 3 | vostok
# Processing Record 29 of Set 3 | albany
# Processing Record 30 of Set 3 | honningsvag
# Processing Record 31 of Set 3 | yellowknife
# Processing Record 32 of Set 3 | ballina
# Processing Record 33 of Set 3 | kannur
# Processing Record 34 of Set 3 | marsh harbour
# Processing Record 35 of Set 3 | bay roberts
# Processing Record 36 of Set 3 | bilma
# Processing Record 37 of Set 3 | vangaindrano
# Processing Record 38 of Set 3 | codrington
# Processing Record 39 of Set 3 | el ermitano
# Processing Record 40 of Set 3 | mar del plata
# Processing Record 41 of Set 3 | tyumentsevo
# Processing Record 42 of Set 3 | iqaluit
# Processing Record 43 of Set 3 | darhan
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | buala
# Processing Record 46 of Set 3 | fortuna
# Processing Record 47 of Set 3 | bonavista
# Processing Record 48 of Set 3 | batagay
# Processing Record 49 of Set 3 | faanui
# Processing Record 50 of Set 3 | new norfolk
# Processing Record 1 of Set 4 | komsomolskiy
# Processing Record 2 of Set 4 | bitung
# Processing Record 3 of Set 4 | grand-lahou
# Processing Record 4 of Set 4 | saint-augustin
# Processing Record 5 of Set 4 | spas-demensk
# Processing Record 6 of Set 4 | pomerode
# Processing Record 7 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 4 | bathsheba
# Processing Record 9 of Set 4 | sitka
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | samarai
# Processing Record 12 of Set 4 | hithadhoo
# Processing Record 13 of Set 4 | beamsville
# Processing Record 14 of Set 4 | tashigang
# Processing Record 15 of Set 4 | flin flon
# Processing Record 16 of Set 4 | dudinka
# Processing Record 17 of Set 4 | cairns
# Processing Record 18 of Set 4 | mahebourg
# Processing Record 19 of Set 4 | meteti
# Processing Record 20 of Set 4 | puri
# Processing Record 21 of Set 4 | fatehpur
# Processing Record 22 of Set 4 | eydhafushi
# Processing Record 23 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 4 | waddan
# Processing Record 25 of Set 4 | kamaishi
# Processing Record 26 of Set 4 | baringo
# Processing Record 27 of Set 4 | vardo
# Processing Record 28 of Set 4 | opuwo
# Processing Record 29 of Set 4 | arman
# Processing Record 30 of Set 4 | aranda de duero
# Processing Record 31 of Set 4 | berlevag
# Processing Record 32 of Set 4 | mattru
# Processing Record 33 of Set 4 | hirson
# Processing Record 34 of Set 4 | san patricio
# Processing Record 35 of Set 4 | angoram
# Processing Record 36 of Set 4 | broken hill
# Processing Record 37 of Set 4 | creel
# Processing Record 38 of Set 4 | talnakh
# Processing Record 39 of Set 4 | mulbagal
# Processing Record 40 of Set 4 | gazanjyk
# Processing Record 41 of Set 4 | muisne
# Processing Record 42 of Set 4 | lorengau
# Processing Record 43 of Set 4 | ostrovnoy
# Processing Record 44 of Set 4 | tucumcari
# Processing Record 45 of Set 4 | tobol
# Processing Record 46 of Set 4 | seoul
# Processing Record 47 of Set 4 | the valley
# Processing Record 48 of Set 4 | yar-sale
# Processing Record 49 of Set 4 | thinadhoo
# Processing Record 50 of Set 4 | puerto del rosario
# Processing Record 1 of Set 5 | hay river
# Processing Record 2 of Set 5 | saint-joseph
# Processing Record 3 of Set 5 | acarau
# Processing Record 4 of Set 5 | hami
# Processing Record 5 of Set 5 | beidao
# Processing Record 6 of Set 5 | port macquarie
# Processing Record 7 of Set 5 | lavrentiya
# Processing Record 8 of Set 5 | alto baudo
# City not found. Skipping...
# Processing Record 9 of Set 5 | havoysund
# Processing Record 10 of Set 5 | cockburn town
# Processing Record 11 of Set 5 | segovia
# Processing Record 12 of Set 5 | husavik
# Processing Record 13 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 5 | kodiak
# Processing Record 15 of Set 5 | sorland
# Processing Record 16 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 17 of Set 5 | kabelvag
# Processing Record 18 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 5 | naze
# Processing Record 20 of Set 5 | kurchum
# Processing Record 21 of Set 5 | beloha
# Processing Record 22 of Set 5 | yarada
# Processing Record 23 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 5 | bato
# Processing Record 25 of Set 5 | cayenne
# Processing Record 26 of Set 5 | severo-kurilsk
# Processing Record 27 of Set 5 | tamiahua
# Processing Record 28 of Set 5 | sydney
# Processing Record 29 of Set 5 | preobrazheniye
# Processing Record 30 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 5 | rusape
# Processing Record 32 of Set 5 | yerbogachen
# Processing Record 33 of Set 5 | raton
# Processing Record 34 of Set 5 | lyubymivka
# Processing Record 35 of Set 5 | asau
# Processing Record 36 of Set 5 | pasni
# Processing Record 37 of Set 5 | kavaratti
# Processing Record 38 of Set 5 | rawson
# Processing Record 39 of Set 5 | pacific grove
# Processing Record 40 of Set 5 | basco
# Processing Record 41 of Set 5 | barguzin
# Processing Record 42 of Set 5 | mabaruma
# Processing Record 43 of Set 5 | koutiala
# Processing Record 44 of Set 5 | sulangan
# Processing Record 45 of Set 5 | fria
# Processing Record 46 of Set 5 | gryfice
# Processing Record 47 of Set 5 | sayyan
# Processing Record 48 of Set 5 | nanortalik
# Processing Record 49 of Set 5 | sovetskaya gavan
# Processing Record 50 of Set 5 | maniitsoq
# Processing Record 1 of Set 6 | paranaiba
# Processing Record 2 of Set 6 | itacarambi
# Processing Record 3 of Set 6 | mosetse
# Processing Record 4 of Set 6 | puerto leguizamo
# Processing Record 5 of Set 6 | ust-nera
# Processing Record 6 of Set 6 | kangaatsiaq
# Processing Record 7 of Set 6 | karymskoye
# Processing Record 8 of Set 6 | west wendover
# Processing Record 9 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 6 | rocha
# Processing Record 11 of Set 6 | tonj
# Processing Record 12 of Set 6 | port hardy
# Processing Record 13 of Set 6 | grande prairie
# Processing Record 14 of Set 6 | anadyr
# Processing Record 15 of Set 6 | kiunga
# Processing Record 16 of Set 6 | manasa
# Processing Record 17 of Set 6 | abeche
# Processing Record 18 of Set 6 | igrim
# Processing Record 19 of Set 6 | qasigiannguit
# Processing Record 20 of Set 6 | tra vinh
# Processing Record 21 of Set 6 | belaya gora
# Processing Record 22 of Set 6 | rockhampton
# Processing Record 23 of Set 6 | katherine
# Processing Record 24 of Set 6 | ixtapa
# Processing Record 25 of Set 6 | padang
# Processing Record 26 of Set 6 | santa rita
# Processing Record 27 of Set 6 | praia da vitoria
# Processing Record 28 of Set 6 | fontanka
# Processing Record 29 of Set 6 | nola
# Processing Record 30 of Set 6 | tecoanapa
# Processing Record 31 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 32 of Set 6 | los llanos de aridane
# Processing Record 33 of Set 6 | san carlos de bariloche
# Processing Record 34 of Set 6 | rundu
# Processing Record 35 of Set 6 | altay
# Processing Record 36 of Set 6 | casalpusterlengo
# Processing Record 37 of Set 6 | wasilla
# Processing Record 38 of Set 6 | gunjur
# Processing Record 39 of Set 6 | pinawa
# Processing Record 40 of Set 6 | sioux lookout
# Processing Record 41 of Set 6 | sobolevo
# Processing Record 42 of Set 6 | pak phanang
# Processing Record 43 of Set 6 | necochea
# Processing Record 44 of Set 6 | zhigalovo
# Processing Record 45 of Set 6 | les cayes
# Processing Record 46 of Set 6 | ocos
# Processing Record 47 of Set 6 | tynda
# Processing Record 48 of Set 6 | charters towers
# Processing Record 49 of Set 6 | belmonte
# Processing Record 50 of Set 6 | lamont
# Processing Record 1 of Set 7 | naantali
# Processing Record 2 of Set 7 | ivdel
# Processing Record 3 of Set 7 | hasaki
# Processing Record 4 of Set 7 | ous
# Processing Record 5 of Set 7 | ayan
# Processing Record 6 of Set 7 | pointe michel
# Processing Record 7 of Set 7 | candolim
# Processing Record 8 of Set 7 | mana
# Processing Record 9 of Set 7 | nan
# Processing Record 10 of Set 7 | fatehgarh
# Processing Record 11 of Set 7 | alta floresta
# Processing Record 12 of Set 7 | umm jarr
# City not found. Skipping...
# Processing Record 13 of Set 7 | saldanha
# Processing Record 14 of Set 7 | dubbo
# Processing Record 15 of Set 7 | kaitangata
# Processing Record 16 of Set 7 | san quintin
# Processing Record 17 of Set 7 | catamarca
# Processing Record 18 of Set 7 | barcelos
# Processing Record 19 of Set 7 | bowen
# Processing Record 20 of Set 7 | pangai
# Processing Record 21 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 23 of Set 7 | burica
# City not found. Skipping...
# Processing Record 24 of Set 7 | wajir
# Processing Record 25 of Set 7 | ketchikan
# Processing Record 26 of Set 7 | tessalit
# Processing Record 27 of Set 7 | sumenep
# Processing Record 28 of Set 7 | auki
# Processing Record 29 of Set 7 | beberibe
# Processing Record 30 of Set 7 | roebourne
# Processing Record 31 of Set 7 | mogadishu
# Processing Record 32 of Set 7 | pasighat
# Processing Record 33 of Set 7 | vostochnyy
# Processing Record 34 of Set 7 | lata
# Processing Record 35 of Set 7 | geraldton
# Processing Record 36 of Set 7 | plattsburgh
# Processing Record 37 of Set 7 | atar
# Processing Record 38 of Set 7 | norman wells
# Processing Record 39 of Set 7 | duncan
# Processing Record 40 of Set 7 | banyo
# Processing Record 41 of Set 7 | faya
# Processing Record 42 of Set 7 | gat
# Processing Record 43 of Set 7 | verkh-usugli
# Processing Record 44 of Set 7 | altamont
# Processing Record 45 of Set 7 | mazulskiy
# City not found. Skipping...
# Processing Record 46 of Set 7 | fairbanks
# Processing Record 47 of Set 7 | marsa matruh
# Processing Record 48 of Set 7 | harper
# Processing Record 49 of Set 7 | binzhou
# Processing Record 50 of Set 7 | kaeo
# Processing Record 1 of Set 8 | tuktoyaktuk
# Processing Record 2 of Set 8 | henties bay
# Processing Record 3 of Set 8 | yefimovskiy
# City not found. Skipping...
# Processing Record 4 of Set 8 | naigarhi
# Processing Record 5 of Set 8 | mobara
# Processing Record 6 of Set 8 | mujiayingzi
# Processing Record 7 of Set 8 | husum
# Processing Record 8 of Set 8 | guerrero negro
# Processing Record 9 of Set 8 | te anau
# Processing Record 10 of Set 8 | makakilo city
# Processing Record 11 of Set 8 | esso
# Processing Record 12 of Set 8 | longyearbyen
# Processing Record 13 of Set 8 | montijo
# Processing Record 14 of Set 8 | cangucu
# Processing Record 15 of Set 8 | clyde river
# Processing Record 16 of Set 8 | biak
# Processing Record 17 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 18 of Set 8 | avera
# Processing Record 19 of Set 8 | ginir
# Processing Record 20 of Set 8 | hambantota
# Processing Record 21 of Set 8 | kirakira
# Processing Record 22 of Set 8 | margate
# Processing Record 23 of Set 8 | chulman
# Processing Record 24 of Set 8 | murgab
# Processing Record 25 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 8 | perbaungan
# Processing Record 27 of Set 8 | letterkenny
# Processing Record 28 of Set 8 | floro
# Processing Record 29 of Set 8 | iquitos
# Processing Record 30 of Set 8 | luganville
# Processing Record 31 of Set 8 | bukama
# Processing Record 32 of Set 8 | sola
# Processing Record 33 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 8 | saskylakh
# Processing Record 36 of Set 8 | itarema
# Processing Record 37 of Set 8 | grindavik
# Processing Record 38 of Set 8 | alofi
# Processing Record 39 of Set 8 | concepcion del oro
# Processing Record 40 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 8 | sao joao da barra
# Processing Record 42 of Set 8 | nador
# Processing Record 43 of Set 8 | tairua
# Processing Record 44 of Set 8 | kutum
# Processing Record 45 of Set 8 | coquimbo
# Processing Record 46 of Set 8 | erzin
# Processing Record 47 of Set 8 | la ronge
# Processing Record 48 of Set 8 | tabou
# Processing Record 49 of Set 8 | zheleznodorozhnyy
# Processing Record 50 of Set 8 | quthing
# Processing Record 1 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 2 of Set 9 | luderitz
# Processing Record 3 of Set 9 | adwa
# Processing Record 4 of Set 9 | urucara
# Processing Record 5 of Set 9 | marawi
# Processing Record 6 of Set 9 | bull savanna
# Processing Record 7 of Set 9 | sargur
# Processing Record 8 of Set 9 | svetlogorsk
# Processing Record 9 of Set 9 | mehamn
# Processing Record 10 of Set 9 | agropoli
# Processing Record 11 of Set 9 | la asuncion
# Processing Record 12 of Set 9 | saint george
# Processing Record 13 of Set 9 | jinan
# Processing Record 14 of Set 9 | gigmoto
# Processing Record 15 of Set 9 | alto piquiri
# Processing Record 16 of Set 9 | svetlyy
# Processing Record 17 of Set 9 | abancay
# Processing Record 18 of Set 9 | rio tinto
# Processing Record 19 of Set 9 | omboue
# Processing Record 20 of Set 9 | nusaybin
# Processing Record 21 of Set 9 | tautira
# Processing Record 22 of Set 9 | springbok
# Processing Record 23 of Set 9 | winnemucca
# Processing Record 24 of Set 9 | mahanoro
# Processing Record 25 of Set 9 | pangnirtung
# Processing Record 26 of Set 9 | benjamin constant
# Processing Record 27 of Set 9 | senador jose porfirio
# Processing Record 28 of Set 9 | souillac
# Processing Record 29 of Set 9 | arlit
# Processing Record 30 of Set 9 | salinopolis
# Processing Record 31 of Set 9 | asekeyevo
# Processing Record 32 of Set 9 | san onofre
# Processing Record 33 of Set 9 | champerico
# Processing Record 34 of Set 9 | bouna
# Processing Record 35 of Set 9 | moju
# Processing Record 36 of Set 9 | zhaozhou
# Processing Record 37 of Set 9 | ryotsu
# Processing Record 38 of Set 9 | salalah
# Processing Record 39 of Set 9 | batemans bay
# Processing Record 40 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 41 of Set 9 | hualmay
# Processing Record 42 of Set 9 | kupino
# Processing Record 43 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 9 | platanos
# Processing Record 45 of Set 9 | zhigansk
# Processing Record 46 of Set 9 | tigil
# Processing Record 47 of Set 9 | severnyy
# Processing Record 48 of Set 9 | taoudenni
# Processing Record 49 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 50 of Set 9 | gimli
# Processing Record 1 of Set 10 | bosaso
# Processing Record 2 of Set 10 | valladolid
# Processing Record 3 of Set 10 | tunceli
# Processing Record 4 of Set 10 | udachnyy
# Processing Record 5 of Set 10 | diffa
# Processing Record 6 of Set 10 | lons
# Processing Record 7 of Set 10 | bandarbeyla
# Processing Record 8 of Set 10 | isangel
# Processing Record 9 of Set 10 | porto franco
# Processing Record 10 of Set 10 | lalmohan
# Processing Record 11 of Set 10 | rabat
# Processing Record 12 of Set 10 | onguday
# Processing Record 13 of Set 10 | natal
# Processing Record 14 of Set 10 | sakakah
# Processing Record 15 of Set 10 | san cristobal
# Processing Record 16 of Set 10 | oktyabrskiy
# Processing Record 17 of Set 10 | bambanglipuro
# Processing Record 18 of Set 10 | ambovombe
# Processing Record 19 of Set 10 | qeshm
# Processing Record 20 of Set 10 | aberdeen
# Processing Record 21 of Set 10 | portland
# Processing Record 22 of Set 10 | gizo
# Processing Record 23 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 24 of Set 10 | nobeoka
# Processing Record 25 of Set 10 | dalbandin
# Processing Record 26 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 10 | levelland
# Processing Record 28 of Set 10 | port hawkesbury
# Processing Record 29 of Set 10 | nantucket
# Processing Record 30 of Set 10 | prince rupert
# Processing Record 31 of Set 10 | paamiut
# Processing Record 32 of Set 10 | liancheng
# Processing Record 33 of Set 10 | khani
# Processing Record 34 of Set 10 | sal rei
# Processing Record 35 of Set 10 | port-gentil
# Processing Record 36 of Set 10 | salta
# Processing Record 37 of Set 10 | kanniyakumari
# Processing Record 38 of Set 10 | ouegoa
# Processing Record 39 of Set 10 | uusikaupunki
# Processing Record 40 of Set 10 | guiratinga
# Processing Record 41 of Set 10 | jaipur
# Processing Record 42 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 43 of Set 10 | yinchuan
# Processing Record 44 of Set 10 | san juan de abajo
# Processing Record 45 of Set 10 | darque
# Processing Record 46 of Set 10 | ahipara
# Processing Record 47 of Set 10 | tomino
# Processing Record 48 of Set 10 | bolshiye uki
# City not found. Skipping...
# Processing Record 49 of Set 10 | amapa
# Processing Record 50 of Set 10 | neuquen
# Processing Record 1 of Set 11 | castilho
# Processing Record 2 of Set 11 | yulara
# Processing Record 3 of Set 11 | mapiripan
# Processing Record 4 of Set 11 | sandpoint
# Processing Record 5 of Set 11 | sao filipe
# Processing Record 6 of Set 11 | baie-comeau
# Processing Record 7 of Set 11 | gao
# Processing Record 8 of Set 11 | el torno
# Processing Record 9 of Set 11 | cabadiangan
# Processing Record 10 of Set 11 | thoen
# Processing Record 11 of Set 11 | ilulissat
# Processing Record 12 of Set 11 | vieux fort
# Processing Record 13 of Set 11 | tiksi
# Processing Record 14 of Set 11 | tual
# Processing Record 15 of Set 11 | namibe
# Processing Record 16 of Set 11 | aguazul
# Processing Record 17 of Set 11 | rapid valley
# Processing Record 18 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 11 | hutchinson
# Processing Record 20 of Set 11 | jabinyanah
# Processing Record 21 of Set 11 | ahtopol
# Processing Record 22 of Set 11 | labuan
# Processing Record 23 of Set 11 | narsaq
# Processing Record 24 of Set 11 | craig
# Processing Record 25 of Set 11 | whitianga
# Processing Record 26 of Set 11 | bolobo
# Processing Record 27 of Set 11 | comarapa
# Processing Record 28 of Set 11 | matipo
# Processing Record 29 of Set 11 | umtata
# Processing Record 30 of Set 11 | gamba
# Processing Record 31 of Set 11 | benemerito de las americas
# Processing Record 32 of Set 11 | bacolod
# Processing Record 33 of Set 11 | arequipa
# Processing Record 34 of Set 11 | camana
# Processing Record 35 of Set 11 | nkhotakota
# Processing Record 36 of Set 11 | west bay
# Processing Record 37 of Set 11 | mandalgovi
# Processing Record 38 of Set 11 | balkanabat
# Processing Record 39 of Set 11 | puerto baquerizo moreno
# Processing Record 40 of Set 11 | eregli
# Processing Record 41 of Set 11 | celestun
# Processing Record 42 of Set 11 | assiniboia
# Processing Record 43 of Set 11 | waitati
# Processing Record 44 of Set 11 | san vicente
# Processing Record 45 of Set 11 | xai-xai
# Processing Record 46 of Set 11 | abu samrah
# Processing Record 47 of Set 11 | kushiro
# Processing Record 48 of Set 11 | viedma
# Processing Record 49 of Set 11 | motygino
# Processing Record 50 of Set 11 | paysandu
# Processing Record 1 of Set 12 | port hedland
# Processing Record 2 of Set 12 | roseburg
# Processing Record 3 of Set 12 | palora
# Processing Record 4 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 5 of Set 12 | anchorage
# Processing Record 6 of Set 12 | mao
# Processing Record 7 of Set 12 | kieta
# Processing Record 8 of Set 12 | meadow lake
# Processing Record 9 of Set 12 | talaya
# Processing Record 10 of Set 12 | dwarka
# Processing Record 11 of Set 12 | nakhon thai
# Processing Record 12 of Set 12 | touros
# Processing Record 13 of Set 12 | sibolga
# Processing Record 14 of Set 12 | jalu
# Processing Record 15 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 16 of Set 12 | port moresby
# Processing Record 17 of Set 12 | tromso
# Processing Record 18 of Set 12 | richards bay
# Processing Record 19 of Set 12 | aripuana
# Processing Record 20 of Set 12 | norden
# Processing Record 21 of Set 12 | cabedelo
# Processing Record 22 of Set 12 | lujan
# Processing Record 23 of Set 12 | klaksvik
# Processing Record 24 of Set 12 | diego de almagro
# Processing Record 25 of Set 12 | tagana-an
# Processing Record 26 of Set 12 | macamic
# Processing Record 27 of Set 12 | shubarshi
# Processing Record 28 of Set 12 | olafsvik
# Processing Record 29 of Set 12 | lima
# Processing Record 30 of Set 12 | aksu
# Processing Record 31 of Set 12 | fort nelson
# Processing Record 32 of Set 12 | zabaykalsk
# Processing Record 33 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 34 of Set 12 | revda
# Processing Record 35 of Set 12 | manado
# Processing Record 36 of Set 12 | haines junction
# Processing Record 37 of Set 12 | nedjo
# Processing Record 38 of Set 12 | eirunepe
# Processing Record 39 of Set 12 | cervo
# Processing Record 40 of Set 12 | saint-georges
# Processing Record 41 of Set 12 | quelimane
# Processing Record 42 of Set 12 | ormara
# Processing Record 43 of Set 12 | los altos
# Processing Record 44 of Set 12 | macae
# Processing Record 45 of Set 12 | riosucio
# Processing Record 46 of Set 12 | huainan
# Processing Record 47 of Set 12 | kabare
# Processing Record 48 of Set 12 | lishu
# Processing Record 49 of Set 12 | buraydah
# Processing Record 50 of Set 12 | newport
# Processing Record 1 of Set 13 | lixourion
# Processing Record 2 of Set 13 | chuy
# Processing Record 3 of Set 13 | porto novo
# Processing Record 4 of Set 13 | polyarnyy
# Processing Record 5 of Set 13 | northam
# Processing Record 6 of Set 13 | beatrice
# Processing Record 7 of Set 13 | shimoda
# Processing Record 8 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 9 of Set 13 | anzio
# Processing Record 10 of Set 13 | muros
# Processing Record 11 of Set 13 | flinders
# Processing Record 12 of Set 13 | oyama
# Processing Record 13 of Set 13 | matay
# Processing Record 14 of Set 13 | camacha
# Processing Record 15 of Set 13 | inuvik
# Processing Record 16 of Set 13 | whitehorse
# Processing Record 17 of Set 13 | nome
# Processing Record 18 of Set 13 | busca
# Processing Record 19 of Set 13 | kyshtovka
# Processing Record 20 of Set 13 | safaga
# Processing Record 21 of Set 13 | madimba
# Processing Record 22 of Set 13 | horsham
# Processing Record 23 of Set 13 | daoukro
# Processing Record 24 of Set 13 | mecca
# Processing Record 25 of Set 13 | moses lake
# Processing Record 26 of Set 13 | ternate
# Processing Record 27 of Set 13 | makokou
# Processing Record 28 of Set 13 | wanaka
# Processing Record 29 of Set 13 | rexburg
# Processing Record 30 of Set 13 | alice springs
# Processing Record 31 of Set 13 | utiel
# Processing Record 32 of Set 13 | qaqortoq
# Processing Record 33 of Set 13 | slave lake
# Processing Record 34 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 35 of Set 13 | lubango
# Processing Record 36 of Set 13 | hun
# Processing Record 37 of Set 13 | teya
# Processing Record 38 of Set 13 | hammerfest
# Processing Record 39 of Set 13 | kamina
# Processing Record 40 of Set 13 | haverfordwest
# Processing Record 41 of Set 13 | miram shah
# Processing Record 42 of Set 13 | sault sainte marie
# Processing Record 43 of Set 13 | nemuro
# Processing Record 44 of Set 13 | hofn
# Processing Record 45 of Set 13 | polunochnoye
# Processing Record 46 of Set 13 | kunming
# Processing Record 47 of Set 13 | uray
# Processing Record 48 of Set 13 | nicoya
# Processing Record 49 of Set 13 | sao jose da coroa grande
# Processing Record 50 of Set 13 | kalakamati
# Processing Record 1 of Set 14 | ikalamavony
# Processing Record 2 of Set 14 | uvarovka
# Processing Record 3 of Set 14 | huarmey
# Processing Record 4 of Set 14 | cakovec
# Processing Record 5 of Set 14 | ust-omchug
# Processing Record 6 of Set 14 | windsor
# Processing Record 7 of Set 14 | emerald
# Processing Record 8 of Set 14 | punta alta
# Processing Record 9 of Set 14 | boca do acre
# Processing Record 10 of Set 14 | soni
# Processing Record 11 of Set 14 | tura
# Processing Record 12 of Set 14 | yuzhno-kurilsk
# Processing Record 13 of Set 14 | bonfim
# Processing Record 14 of Set 14 | vanimo
# Processing Record 15 of Set 14 | bereda
# Processing Record 16 of Set 14 | tilichiki
# Processing Record 17 of Set 14 | zaranj
# Processing Record 18 of Set 14 | tecpan
# Processing Record 19 of Set 14 | burnie
# Processing Record 20 of Set 14 | angoche
# Processing Record 21 of Set 14 | arrecife
# Processing Record 22 of Set 14 | meridian
# Processing Record 23 of Set 14 | finschhafen
# Processing Record 24 of Set 14 | martil
# Processing Record 25 of Set 14 | dickinson
# Processing Record 26 of Set 14 | belle fourche
# Processing Record 27 of Set 14 | boa vista
# Processing Record 28 of Set 14 | ilek
# Processing Record 29 of Set 14 | labuhan
# Processing Record 30 of Set 14 | tezu
# Processing Record 31 of Set 14 | igarka
# Processing Record 32 of Set 14 | coihaique
# Processing Record 33 of Set 14 | gravdal
# Processing Record 34 of Set 14 | poso
# Processing Record 35 of Set 14 | marystown
# Processing Record 36 of Set 14 | ihosy
# Processing Record 37 of Set 14 | lagoa
# Processing Record 38 of Set 14 | kuytun
# Processing Record 39 of Set 14 | bam
# Processing Record 40 of Set 14 | bardiyah
# Processing Record 41 of Set 14 | tongliao
# Processing Record 42 of Set 14 | vila velha
# Processing Record 43 of Set 14 | soyo
# Processing Record 44 of Set 14 | valdemarpils
# Processing Record 45 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 14 | nanga eboko
# Processing Record 47 of Set 14 | chone
# Processing Record 48 of Set 14 | luoyang
# Processing Record 49 of Set 14 | archidona
# Processing Record 50 of Set 14 | novoagansk
# Processing Record 1 of Set 15 | follonica
# Processing Record 2 of Set 15 | toguchin
# Processing Record 3 of Set 15 | lebedinyy
# Processing Record 4 of Set 15 | divnomorskoye
# Processing Record 5 of Set 15 | thessalon
# Processing Record 6 of Set 15 | elk city
# Processing Record 7 of Set 15 | neiafu
# Processing Record 8 of Set 15 | banbury
# Processing Record 9 of Set 15 | herat
# Processing Record 10 of Set 15 | saint-francois
# Processing Record 11 of Set 15 | doctor arroyo
# Processing Record 12 of Set 15 | wanning
# Processing Record 13 of Set 15 | leh
# Processing Record 14 of Set 15 | popondetta
# Processing Record 15 of Set 15 | krasnokamensk
# Processing Record 16 of Set 15 | oksovskiy
# Processing Record 17 of Set 15 | mosquera
# Processing Record 18 of Set 15 | lesnyye polyany
# Processing Record 19 of Set 15 | tocopilla
# Processing Record 20 of Set 15 | kenai
# Processing Record 21 of Set 15 | bama
# Processing Record 22 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 15 | nabire
# Processing Record 24 of Set 15 | raudeberg
# Processing Record 25 of Set 15 | mut
# Processing Record 26 of Set 15 | sabaudia
# Processing Record 27 of Set 15 | talakan
# Processing Record 28 of Set 15 | askino
# Processing Record 29 of Set 15 | killam
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Lexington      US  37.9887  -84.4777     25.92        67          43
# 1      Cherskiy      RU  68.7500  161.3000    -19.77        97         100
# 2        Atuona      PF  -9.8000 -139.0333     76.86        81          24
# 3        Dikson      RU  73.5069   80.5464    -15.90        97          99
# 4  Kruisfontein      ZA -34.0033   24.7314     73.92        53          49
# 5     Esperance      AU -33.8667  121.9000     64.22        75          41
# 6         Kapaa      US  22.0752 -159.3190     75.33        66          64
# 7          Hovd      MN  48.0056   91.6419     18.07        39           6
# 8     Busselton      AU -33.6500  115.3333     65.66        49           1
# 9     Jamestown      US  42.0970  -79.2353     26.74        96          99
#
#    Wind Speed Current Description                 Date
# 0        6.38    scattered clouds  2021-11-29 09:34:05
# 1        4.03     overcast clouds  2021-11-29 09:37:33
# 2       15.82          light rain  2021-11-29 09:37:33
# 3       19.33     overcast clouds  2021-11-29 09:37:33
# 4       11.39    scattered clouds  2021-11-29 09:37:34
# 5       13.11    scattered clouds  2021-11-29 09:37:35
# 6       18.43       broken clouds  2021-11-29 09:37:35
# 7        1.86           clear sky  2021-11-29 09:37:35
# 8       16.26           clear sky  2021-11-29 09:35:16
# 9        8.19          light snow  2021-11-29 09:37:36

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
#Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label = "City_ID")
